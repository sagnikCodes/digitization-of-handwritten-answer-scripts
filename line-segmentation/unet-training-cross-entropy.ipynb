# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL.Image import fromarray
from torchvision import transforms
import math
import torch
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from pytesseract import image_to_string

# %%
def plot_tensor(img, axis='off'):
    plt.imshow(img.permute(1, 2, 0), cmap='gray')
    if axis == 'off':
        plt.axis('off')
    plt.show()

# %%
class MaskDataset(Dataset):
    def __init__(self, images, masks):
        self.images = images
        self.masks = masks
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        return (self.images[idx], self.masks[idx])

# %%
dataset = torch.load('/kaggle/input/iam-forms-masks/mask_dataset.pt')

# %%
from torch.utils.data import random_split
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Calculate the dataset lengths
total_length = len(dataset)
train_length = int(train_ratio * total_length)
val_length = int(val_ratio * total_length)
test_length = total_length - train_length - val_length

# Split the dataset into train, validation, and test sets
train_set, val_set, test_set = random_split(dataset, [train_length, val_length, test_length])

# %%
train_loader = DataLoader(train_set, batch_size=1, shuffle=True)
val_loader = DataLoader(val_set, batch_size=1, shuffle=False)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
class ConvolutionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.2):
        super().__init__()
        self.conv1 = nn.Conv2d(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=3,
            padding=1
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.dropout1 = nn.Dropout2d(dropout_rate)
        self.conv2 = nn.Conv2d(
            in_channels=out_channels,
            out_channels=out_channels,
            kernel_size=3,
            padding=1
        )
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.dropout2 = nn.Dropout2d(dropout_rate)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.dropout1(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.dropout2(x)
        return x

# %%
class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = ConvolutionBlock(in_channels, out_channels)
        self.pool = nn.MaxPool2d((2, 2))

    def forward(self, x):
        x = self.conv(x)
        output = self.pool(x)
        return x, output

# %%
class DecoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.2):
        super().__init__()
        self.conv_transpose = nn.ConvTranspose2d(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=2,
            stride=2,
            padding=0
        )

        self.conv = ConvolutionBlock(in_channels + out_channels, out_channels, dropout_rate)

    def forward(self, x, skip_connection):
        x = self.conv_transpose(x)
        x = torch.cat([x, skip_connection], axis=1)
        x = self.conv(x)

        return x

# %%
class UNet(nn.Module):
    def __init__(self, num_classes=2):
        super(UNet, self).__init__()
        
        self.enc1 = EncoderBlock(1, 16)
        self.enc2 = EncoderBlock(16, 32)
        self.enc3 = EncoderBlock(32, 64)
        
        self.dec1 = DecoderBlock(64, 32)
        self.dec2 = DecoderBlock(32, 16)
        self.dec3 = DecoderBlock(16, num_classes)
        
    def forward(self, x):
        skip_conn1, x = self.enc1(x)
        skip_conn2, x = self.enc2(x)
        skip_conn3, x = self.enc3(x)

        x = self.dec1(x, skip_conn3)
        x = self.dec2(x, skip_conn2)
        x = self.dec3(x, skip_conn1)
        
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
unet = UNet(num_classes=2).to(device)

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(unet.parameters(), lr=1e-1)

# %%
num_epochs = 100
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    running_loss = 0.0
    for images, masks in train_loader:
        images = F.interpolate(images, size=(1024, 1024), mode='bilinear', align_corners=False).to(device)
        masks = F.interpolate(masks, size=(1024, 1024), mode='bilinear', align_corners=False)
        masks = masks.reshape(masks.shape[0], masks.shape[2], masks.shape[3])
        masks = masks.type(torch.LongTensor).to(device)

        optimizer.zero_grad()
        outputs = unet(images)
        softmax = F.softmax(outputs, dim=1)
        loss = criterion(softmax, masks)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        torch.cuda.empty_cache()

    train_loss = running_loss / len(train_loader)
    train_losses.append(train_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss:.4f}', end=', ')

    unet.eval()
    val_loss = 0.0
    for val_images, val_masks in val_loader:
        val_images = F.interpolate(val_images, size=(1024, 1024), mode='bilinear', align_corners=False).to(device)
        val_masks = F.interpolate(val_masks, size=(1024, 1024), mode='bilinear', align_corners=False)
        val_masks = val_masks.reshape(val_masks.shape[0], val_masks.shape[2], val_masks.shape[3])
        val_masks = val_masks.type(torch.LongTensor).to(device)

        with torch.no_grad():
            val_outputs = unet(val_images)
            val_softmax = F.softmax(val_outputs, dim=1)
            val_loss += criterion(val_softmax, val_masks).item()
            
        torch.cuda.empty_cache()

    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    print(f'Validation Loss: {val_loss:.4f}')
    unet.train()
# Out:
# Epoch [1/100], Training Loss: 0.5614, Validation Loss: 0.6266
# Epoch [2/100], Training Loss: 0.5501, Validation Loss: 0.4922
# Epoch [3/100], Training Loss: 0.5384, Validation Loss: 0.5309
# Epoch [4/100], Training Loss: 0.5356, Validation Loss: 0.4997
# Epoch [5/100], Training Loss: 0.5341, Validation Loss: 0.4866
# Epoch [6/100], Training Loss: 0.5357, Validation Loss: 0.4843
# Epoch [7/100], Training Loss: 0.5315, Validation Loss: 0.4989
# Epoch [8/100], Training Loss: 0.5305, Validation Loss: 0.4857
# Epoch [9/100], Training Loss: 0.5311, Validation Loss: 0.5177
# Epoch [10/100], Training Loss: 0.5288, Validation Loss: 0.4768
# Epoch [11/100], Training Loss: 0.5287, Validation Loss: 0.4741
# Epoch [12/100], Training Loss: 0.5273, Validation Loss: 0.4779
# Epoch [13/100], Training Loss: 0.5295, Validation Loss: 0.5189
# Epoch [14/100], Training Loss: 0.5231, Validation Loss: 0.4845
# Epoch [15/100], Training Loss: 0.5264, Validation Loss: 0.4758
# Epoch [16/100], Training Loss: 0.5298, Validation Loss: 0.5201
# Epoch [17/100], Training Loss: 0.5270, Validation Loss: 0.4771
# Epoch [18/100], Training Loss: 0.5262, Validation Loss: 0.4729
# Epoch [19/100], Training Loss: 0.5245, Validation Loss: 0.5123
# Epoch [20/100], Training Loss: 0.5228, Validation Loss: 0.4843
# Epoch [21/100], Training Loss: 0.5256, Validation Loss: 0.4735
# Epoch [22/100], Training Loss: 0.5228, Validation Loss: 0.5143
# Epoch [23/100], Training Loss: 0.5259, Validation Loss: 0.4821
# Epoch [24/100], Training Loss: 0.5170, Validation Loss: 0.4810
# Epoch [25/100], Training Loss: 0.5258, Validation Loss: 0.5179
# Epoch [26/100], Training Loss: 0.5269, Validation Loss: 0.4730
# Epoch [27/100], Training Loss: 0.5225, Validation Loss: 0.4862
# Epoch [28/100], Training Loss: 0.5214, Validation Loss: 0.5117
# Epoch [29/100], Training Loss: 0.5264, Validation Loss: 0.4806
# Epoch [30/100], Training Loss: 0.5218, Validation Loss: 0.5861
# Epoch [31/100], Training Loss: 0.5220, Validation Loss: 0.4868
# Epoch [32/100], Training Loss: 0.5214, Validation Loss: 0.5187
# Epoch [33/100], Training Loss: 0.5239, Validation Loss: 0.4818
# Epoch [34/100], Training Loss: 0.5199, Validation Loss: 0.4874
# Epoch [35/100], Training Loss: 0.5211, Validation Loss: 0.5220
# Epoch [36/100], Training Loss: 0.5257, Validation Loss: 0.4800
# Epoch [37/100], Training Loss: 0.5198, Validation Loss: 0.4912
# Epoch [38/100], Training Loss: 0.5229, Validation Loss: 0.4738
# Epoch [39/100], Training Loss: 0.5179, Validation Loss: 0.4741
# Epoch [40/100], Training Loss: 0.5183, Validation Loss: 0.4759
# Epoch [41/100], Training Loss: 0.5203, Validation Loss: 0.4720
# Epoch [42/100], Training Loss: 0.5190, Validation Loss: 0.5219
# Epoch [43/100], Training Loss: 0.5206, Validation Loss: 0.5020
# Epoch [44/100], Training Loss: 0.5217, Validation Loss: 0.4770
# Epoch [45/100], Training Loss: 0.5188, Validation Loss: 0.5055
# Epoch [46/100], Training Loss: 0.5203, Validation Loss: 0.5168
# Epoch [47/100], Training Loss: 0.5223, Validation Loss: 0.4762
# Epoch [48/100], Training Loss: 0.5287, Validation Loss: 0.4708
# Epoch [49/100], Training Loss: 0.5179, Validation Loss: 0.4936
# Epoch [50/100], Training Loss: 0.5254, Validation Loss: 0.5112
# Epoch [51/100], Training Loss: 0.5208, Validation Loss: 0.4736
# Epoch [52/100], Training Loss: 0.5199, Validation Loss: 0.4831
# Epoch [53/100], Training Loss: 0.5256, Validation Loss: 0.4858
# Epoch [54/100], Training Loss: 0.5174, Validation Loss: 0.4788
# Epoch [55/100], Training Loss: 0.5191, Validation Loss: 0.4796
# Epoch [56/100], Training Loss: 0.5167, Validation Loss: 0.4793
# Epoch [57/100], Training Loss: 0.5160, Validation Loss: 0.5073
# Epoch [58/100], Training Loss: 0.5240, Validation Loss: 0.4788
# Epoch [59/100], Training Loss: 0.5235, Validation Loss: 0.5301
# Epoch [60/100], Training Loss: 0.5160, Validation Loss: 0.4745
# Epoch [61/100], Training Loss: 0.5199, Validation Loss: 0.5121
# Epoch [62/100], Training Loss: 0.5219, Validation Loss: 0.5103
# Epoch [63/100], Training Loss: 0.5176, Validation Loss: 0.5196
# Epoch [64/100], Training Loss: 0.5253, Validation Loss: 0.5878
# Epoch [65/100], Training Loss: 0.5205, Validation Loss: 0.5598
# Epoch [66/100], Training Loss: 0.5208, Validation Loss: 0.4797
# Epoch [67/100], Training Loss: 0.5161, Validation Loss: 0.4783
# Epoch [68/100], Training Loss: 0.5218, Validation Loss: 0.5272
# Epoch [69/100], Training Loss: 0.5218, Validation Loss: 0.4715
# Epoch [70/100], Training Loss: 0.5177, Validation Loss: 0.5152
# Epoch [71/100], Training Loss: 0.5183, Validation Loss: 0.5125
# Epoch [72/100], Training Loss: 0.5214, Validation Loss: 0.4871
# Epoch [73/100], Training Loss: 0.5172, Validation Loss: 0.6530
# Epoch [74/100], Training Loss: 0.5172, Validation Loss: 0.5000
# Epoch [75/100], Training Loss: 0.5194, Validation Loss: 0.4724
# Epoch [76/100], Training Loss: 0.5204, Validation Loss: 0.6340
# Epoch [77/100], Training Loss: 0.5209, Validation Loss: 0.5181
# Epoch [78/100], Training Loss: 0.5204, Validation Loss: 0.4716
# Epoch [79/100], Training Loss: 0.5203, Validation Loss: 0.4720
# Epoch [80/100], Training Loss: 0.5188, Validation Loss: 0.4709
# Epoch [81/100], Training Loss: 0.5188, Validation Loss: 0.6828
# Epoch [82/100], Training Loss: 0.5189, Validation Loss: 0.5715
# Epoch [83/100], Training Loss: 0.5200, Validation Loss: 0.4724
# Epoch [84/100], Training Loss: 0.5176, Validation Loss: 0.4734
# Epoch [85/100], Training Loss: 0.5217, Validation Loss: 0.5901
# Epoch [86/100], Training Loss: 0.5175, Validation Loss: 0.6441
# Epoch [87/100], Training Loss: 0.5180, Validation Loss: 0.4837
# Epoch [88/100], Training Loss: 0.5216, Validation Loss: 0.4795
# Epoch [89/100], Training Loss: 0.5171, Validation Loss: 0.4867
# Epoch [90/100], Training Loss: 0.5155, Validation Loss: 0.5148
# Epoch [91/100], Training Loss: 0.5133, Validation Loss: 0.5141
# Epoch [92/100], Training Loss: 0.5180, Validation Loss: 0.5080
# Epoch [93/100], Training Loss: 0.5171, Validation Loss: 0.4914
# Epoch [94/100], Training Loss: 0.5212, Validation Loss: 0.4789
# Epoch [95/100], Training Loss: 0.5187, Validation Loss: 0.4773
# Epoch [96/100], Training Loss: 0.5194, Validation Loss: 0.4786
# Epoch [97/100], Training Loss: 0.5149, Validation Loss: 0.5245
# Epoch [98/100], Training Loss: 0.5147, Validation Loss: 0.4764
# Epoch [99/100], Training Loss: 0.5138, Validation Loss: 0.5170
# Epoch [100/100], Training Loss: 0.5176, Validation Loss: 0.6097

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
torch.save(unet, 'unet_cross_entropy.pth')

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'unet_cross_entropy.pth')
# Out:
# /kaggle/working
# /kaggle/working/unet_cross_entropy.pth

# %%
for images, masks in train_loader:
    images = F.interpolate(images, size=(1024, 1024), mode='bilinear', align_corners=False)
    y_hat = unet.cpu()(images).squeeze()
    channel1, channel2 = y_hat.detach()
    plt.imshow(channel1, cmap=plt.cm.binary)
    plt.show()
    plt.imshow(channel2, cmap=plt.cm.binary)
    plt.show()
    break
